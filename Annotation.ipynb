# %%
import spectral.io.envi as envi 
import numpy as np
import matplotlib.pyplot as plt 
import matplotlib

# %%
dado_green = envi.open('sja3.hdr', 'sja3.rfl')
green_array = np.array(dado_green.load())*10

# %%
x = [0.373400, 0.382900, 0.392500, 0.402100, 0.411700, 0.421400, 0.431100,
 0.440800, 0.450500, 0.460300, 0.470100, 0.479900, 0.489700, 0.499500,
 0.509300, 0.519200, 0.529100, 0.539000, 0.548800, 0.558700, 0.568700,
 0.578600, 0.588500, 0.598400, 0.608300, 0.618200, 0.628200, 0.638100,
 0.648000, 0.657900, 0.667800, 0.677700, 0.665800, 0.675400, 0.684900,
 0.694400, 0.704000, 0.713500, 0.723100, 0.732600, 0.742200, 0.751700,
 0.761300, 0.770900, 0.780400, 0.790000, 0.799600, 0.809200, 0.818700,
 0.828300, 0.837900, 0.847500, 0.857100, 0.866700, 0.876200, 0.885800,
 0.895400, 0.905000, 0.914600, 0.924200, 0.933800, 0.943400, 0.953000,
 0.962600, 0.972200, 0.981800, 0.991400, 1.001100, 1.010700, 1.020300,
 1.029900, 1.039500, 1.049100, 1.058700, 1.068300, 1.077900, 1.087500,
 1.097100, 1.106700, 1.116300, 1.125900, 1.135600, 1.145200, 1.154800,
 1.164400, 1.174000, 1.183600, 1.193200, 1.202800, 1.212400, 1.221900,
 1.231500, 1.241100, 1.250700, 1.260300, 1.269900, 1.251500, 1.261400,
 1.271300, 1.281200, 1.291100, 1.301100, 1.311000, 1.320900, 1.330800,
 1.340700, 1.350700, 1.360600, 1.370500, 1.380400, 1.390400, 1.400300,
 1.410200, 1.420200, 1.430100, 1.440000, 1.450000, 1.459900, 1.469900,
 1.479800, 1.489700, 1.499700, 1.509600, 1.519600, 1.529500, 1.539400,
 1.549400, 1.559300, 1.569300, 1.579200, 1.589200, 1.599100, 1.609100,
 1.619000, 1.628900, 1.638900, 1.648800, 1.658800, 1.668700, 1.678600,
 1.688600, 1.698500, 1.708400, 1.718400, 1.728300, 1.738300, 1.748200,
 1.758100, 1.768100, 1.778000, 1.787900, 1.797800, 1.807800, 1.817700,
 1.827600, 1.837500, 1.847400, 1.857400, 1.867300, 1.877200, 1.877800,
 1.887800, 1.897800, 1.907800, 1.917800, 1.927800, 1.937800, 1.947700,
 1.957700, 1.967700, 1.977700, 1.987700, 1.997700, 2.007600, 2.017600,
 2.027600, 2.037600, 2.047500, 2.057500, 2.067500, 2.077400, 2.087400,
 2.097400, 2.107300, 2.117300, 2.127200, 2.137200, 2.147100, 2.157100,
 2.167000, 2.176900, 2.186900, 2.196800, 2.206800, 2.216700, 2.226600,
 2.236600, 2.246500, 2.256400, 2.266300, 2.276200, 2.286100, 2.296000,
 2.305900, 2.315800, 2.325700, 2.335600, 2.345500, 2.355400, 2.365300,
 2.375200, 2.385100, 2.394900, 2.404800, 2.414700, 2.424500, 2.434400,
 2.444200, 2.454100, 2.463900, 2.473800, 2.483600, 2.493400, 2.503300]

# %%
n = []
for i in range(224):
  n.append(x[i]*1000)

len(n)
# Out:
# 224

# %%
fig, ax1 = plt.subplots()
ax1.plot(n,green_array[205,113,:], color = 'brown', linewidth=3)
ax1.annotate('Bandas suprimidas',xy=(1400, -100),xycoords='data', ha='center',
            xytext=(1600, -100), textcoords='data', size=13)
ax1.annotate('', xy=(1900, -30), xytext=(1380, -30),
            xycoords='data', textcoords='data',
            arrowprops={'arrowstyle': '|-|,widthA=0.2,widthB=0.2', })
ax1.annotate('Caulinita', xy=(2200, 2100),  xycoords='data',
            xytext=(2000, 2700), textcoords='data', size=15,
            arrowprops=dict(facecolor='red', shrink=0.05),
            horizontalalignment='left', verticalalignment='bottom',
            )
ax1.annotate('Gibbsita', xy=(2260, 1900),  xycoords='data',
            xytext=(2300, 2700), textcoords='data', size=15,
            arrowprops=dict(facecolor='blue', shrink=0.05),
            horizontalalignment='left', verticalalignment='top',
            )
ax1.set_title('Solo', size=15)
ax1.set_ylabel('Reflectância', size=15)
ax1.set_xlabel('Comprimento de onda (nm)', size=15)
ax1.grid()
