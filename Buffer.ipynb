# %%
# !pip install geopandas
# Out:
# ...
#      |████████████████████████████████| 1.0MB 29.4MB/s
# ...
#      |████████████████████████████████| 15.4MB 196kB/s
# ...
#      |████████████████████████████████| 6.6MB 32.3MB/s
# ...

# %%
import geopandas as gpd

# %%
hid = gpd.read_file('hidro.shp')
hid.head()
# Out:
#    ARCID  ORDER  ...  LENGTH_KM                                           geometry
# 0      3      2  ...      0.007  LINESTRING (220496.526 8246808.999, 220496.526...
# 1      7      2  ...      0.007  LINESTRING (223286.526 8246808.999, 223286.526...
# 2      8      1  ...      0.427  LINESTRING (222859.026 8246808.999, 223286.526...
# 3      9      3  ...      0.007  LINESTRING (226001.526 8246808.999, 226001.526...
# 4     11      3  ...      0.007  LINESTRING (227051.526 8246808.999, 227051.526...
#
# [5 rows x 6 columns]

# %%
hid.plot()

# %%
buffer = hid['geometry'].buffer(distance=100)
buffer.plot()
